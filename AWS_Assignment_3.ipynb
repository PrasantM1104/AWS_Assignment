# %%
#1) Explain the concept of auto-scaling.

"""
Ans:
Auto-scaling is a function that allows to provision and launch new instances whenever there is a demand without any human intervention. It allows you to automatically increase or decrease resource capacity in relation to the demand.

Based on the configuration and preference, the instance is scaled up or down as per the demand load in the instance. 

Configuration includes, what is the minimum capacity, desired capacity and maximum capacity.

Minimum capacity implies the minimum instances required and this would be always be availbale.
Desired capacity implies the instances required in normal. Under this capacity, usually the application runs maximum period of time.
Maximum capacity implies the maximum instances that is required during peak loads.
"""

# %%
#2) Explain CloudFormation Solution.

"""
Ans:
AWS CloudFormation is a AWS Service that helps to create and manage a collection of AWS resorces (called stack) by provisioning and updating them in a orderly and predictable way. It enables us to manage the complete infrastructure or AWS resources in a text file or template. 

All the resources that are required in a application can easily be deployed using templates is known as "CloudFormation Solution". And the template can reused to replicate our infrastructure in multiple environments.  

CloudFormation utilizes a system called “nested stacks.” That is, CloudFormation  templates being called from within CloudFormation templates. These nested stacks can further be abstracted into StackSets. It should be noted that StackSets require additional permissions, beyond those of normal AWS CloudFormation.  
"""

# %%
#3) Mention and explain AWS services that are not specialized to a specific location.

"""
Ans:
The global AWS services are :
i) IAM - Identity and Access Management: IAM is the heart of security of AWS. It helps to control the access of identities like user, group or role by the help of policy. It authenticates and authorizes the users to use service and resource of AWS and safeguard user account.

ii) Amazon Route 53: Route 53 is a DNS (Domain Name Service) web service which helps to connects user requests to AWS infrastructure such as Amazon EC2 instances, Elastic Load Balancing load balancers, and Amazon S3 buckets, as well as infrastructure outside of AWS.

iii) Web Application Firewall or WAF: It is a firewall helps to monitor the HTTP and HTTPS requests that are forwarded to Amazon CloudFront and control access to the content. Based on conditions that we specify, such as the IP addresses that requests originate from or the values of query strings, CloudFront responds to requests either with the requested content or with an HTTP 403 status code (Forbidden). We can also configure CloudFront to return a custom error page when a request is blocked.

iv) CloudFront: CloudFront is a AWS Content Delivery Network which can easily cached content, like web videos or other hefty files, can be accessed more quickly with content delivery networks. 

"""

# %%
#4) What's the difference between pausing and terminating an Amazon Elastic Compute Cloud instance?

"""
Ans:
Pausing an instance: An instance is paused when we select "Stop Instance" for an EC2 instance. When an instance is stopped, the instance performs a normal shutdown and then transitions to a stopped state. All of its Amazon EBS volumes remain attached, and we can start the instance again at a later time. We are not charged for additional instance hours while the instance is in a stopped state.

Terminating an instance: When an instance is terminated, the instance performs a normal shutdown, then the attached Amazon EBS volumes are deleted unless the volume’s deleteOnTermination attribute is set to false. The instance itself is also deleted, and we can’t start the instance again at a later time.
"""

# %%
#5) Describe how to set up CloudWatch to recover an EC2 instance.

"""
Ans:
Amazon CloudWatch is one of the Amazon Web Service. It is a management tool and basically monitors service for AWS cloud resources and all applications run on the AWS platform.

CloudWatch can be used to track and collect metrics, set alarms, collect and monitor log files, and also monitor resources such as EC2 instances, RDS DB instances, and DynamoDB tables.

When an instance fails a system status check, we can use CloudWatch alarm actions to automatically recover it.

However, the recover option works only for system check failures like network connectivity lost, system power loss, software or hardware issues on physical host etc and it doesnt work for instance status check failures. In addition, if we terminate our instance, we will not be able to recover it with CloudWatch.

To recover EC2 instance, we need to follow below steps:

i) Firstly, we have to open the Amazon EC2 console and go to Instances and select the required instance.

ii) Go to Actions, select Monitor and troubleshoot.

iii) From there go to Manage CloudWatch alarms and click on "Create an alarm"
For creating an alarm we need an AWS Identity and Access Management (IAM) permissions to stop and start the associated instance.

iv) Then for Alarm notification, we can select an existing Amazon Simple Notification Service (Amazon SNS) topic.

v) Click on toggle for Alarm action, and click on Recover.

vi) Next, for Group samples and Type of data to sample, we must give an appropriate statistic and metric for our use case.

vii) And then we must specify the evaluation period for the alarm. Then, modify the Alarm name if we want to. 

viii). Finally, we can click on Create.

The automatic recovery process attempts to recover our instance for up to three separate failures per day.
If the instance system status check failure persists, we can manually stop and start the instance.
"""
